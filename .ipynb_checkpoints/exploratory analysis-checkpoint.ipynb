# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy

# %%
#clean data
wine_dataframe=pd.read_csv("Resources/wine_dataset.csv")
wine_dataframe_clean=wine_dataframe.drop(["Unnamed: 0","region_2"], axis=1)
wine_dataframe_clean
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La B̩gude, named af...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                   designation  points  price  \
# 0                           Martha's Vineyard      96  235.0
# ...

# %%
clean_wine_data=wine_dataframe_clean.dropna()
clean_wine_data
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La B̩gude, named af...
# ...        ...                                                ...
# 150923  France  Rich and toasty, with tiny bubbles. The bouque...
# 150924  France  Really fine for a low-acid vintage, there's an...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
#
#                                   designation  points  price        province  \
# 0                           Martha's Vineyard      96  235.0      California
# ...

# %%
#count breakdown
points_count=clean_wine_data["points"].value_counts()
points_count
# Out:
# 87     10272
# 88      8954
# 90      8588
# 86      7193
# 89      6526
# 91      5870
# 92      5651
# 85      5507
# 84      4739
# 93      3889
# 83      2791
# 94      2283
# 82      1921
# 95      1161
# 81       719
# 80       435
# 96       430
# 97       219
# 98        80
# 99        35
# 100       21
# Name: points, dtype: int64

# %%
variety_count=clean_wine_data["variety"].value_counts()
variety_count
# Out:
# Pinot Noir            8813
# Chardonnay            7754
# Red Blend             7166
# Cabernet Sauvignon    6181
# Syrah                 3438
#                       ...
# Erbaluce                 1
# Grolleau                 1
# Sauvignon Musqu̩        1
# Seyval Blanc             1
# Vidadillo                1
# Name: variety, Length: 427, dtype: int64

# %%
winery_count=clean_wine_data["winery"].value_counts()
winery_count
# Out:
# Williams Selyem              302
# Testarossa                   264
# Kendall-Jackson              214
# Columbia Crest               212
# Trapiche                     184
#                             ...
# Beldui                         1
# Vignobles Boissonneau          1
# Cellers Grifoll Declara        1
# Trou de Bonde                  1
# Chateau de l'Oiselini̬re      1
# Name: winery, Length: 8652, dtype: int64

# %%
price_count=clean_wine_data["price"].value_counts()
price_count
# Out:
# 20.0     4006
# 30.0     3423
# 15.0     3391
# 25.0     3357
# 18.0     2989
#          ...
# 268.0       1
# 248.0       1
# 420.0       1
# 197.0       1
# 142.0       1
# Name: price, Length: 281, dtype: int64
